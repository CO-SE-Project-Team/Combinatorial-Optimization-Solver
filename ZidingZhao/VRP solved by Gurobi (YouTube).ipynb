# %% [markdown]
# https://youtu.be/7_-Xuq2xKdc Gurobi解决VRP问题（Python接口）

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rnd = np.random
rnd.seed(0)

# %%
n = 10
